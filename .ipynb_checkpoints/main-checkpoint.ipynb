# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
# Out:
# 2025-11-21 17:56:59.295583: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
    "./images/train",
    color_mode="rgb",          
    image_size=(48, 48),
    batch_size=32,
    shuffle=True
)

val_ds = tf.keras.utils.image_dataset_from_directory(
    "./images/validation",
    color_mode="rgb",
    image_size=(48, 48),
    batch_size=32
)

class_names = train_ds.class_names
print("Detected classes:", class_names)
# Out:
# Found 28822 files belonging to 7 classes.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1763728025.170300  164776 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2098 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3050 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6
# Found 7066 files belonging to 7 classes.
# Detected classes: ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']

# %%
model = keras.Sequential([
    layers.Rescaling(1./255, input_shape=(48, 48, 3)),

    layers.Conv2D(512, (3,3), activation='relu', padding='same'),
    layers.BatchNormalization(),
    layers.MaxPooling2D(2, 2),
    layers.Dropout(0.25),

    layers.Conv2D(256, (3,3), activation='relu', padding='same'),
    layers.BatchNormalization(),
    layers.MaxPooling2D(2, 2),
    layers.Dropout(0.25),

    layers.Conv2D(128, (3,3), activation='relu', padding='same'),
    layers.BatchNormalization(),
    layers.MaxPooling2D(2, 2),
    layers.Dropout(0.3),

    layers.Conv2D(64, (3,3), activation='relu', padding='same'),
    layers.BatchNormalization(),
    layers.MaxPooling2D(2, 2),
    layers.Dropout(0.3),
    
    layers.Flatten(),
    layers.Dense(32, activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.3),

    layers.Dense(64, activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.4),

    layers.Dense(len(class_names), activation='softmax')
])
# Out:
# /home/ikshvaku/.Python-Env/fea/lib/python3.13/site-packages/keras/src/layers/preprocessing/data_layer.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
initial_lr = 0.01

optimizer = tf.keras.optimizers.Adam(learning_rate=initial_lr)

model.compile(
    optimizer=optimizer,
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

lr_scheduler = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_accuracy',
    factor=0.75,
    patience=3,
    verbose=1,
    min_lr=1e-6
)

history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=50,
    callbacks=[lr_scheduler]
)
# Out:
# Epoch 1/50
# 2025-11-21 17:57:15.361529: I external/local_xla/xla/service/service.cc:163] XLA service 0x7fb898002890 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2025-11-21 17:57:15.361553: I external/local_xla/xla/service/service.cc:171]   StreamExecutor device (0): NVIDIA GeForce RTX 3050 Laptop GPU, Compute Capability 8.6
# 2025-11-21 17:57:15.445398: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-11-21 17:57:15.985261: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:473] Loaded cuDNN version 91600
#   3/901 ━━━━━━━━━━━━━━━━━━━━ 46s 52ms/step - accuracy: 0.1146 - loss: 3.0038
# I0000 00:00:1763728045.672882  164869 device_compiler.h:196] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.2250 - loss: 1.9349
# 2025-11-21 17:58:22.307631: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:310] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.21GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-11-21 17:58:27.347984: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:310] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.19GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 75s 69ms/step - accuracy: 0.2531 - loss: 1.8178 - val_accuracy: 0.2304 - val_loss: 2.0280 - learning_rate: 0.0100
# Epoch 2/50
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 50s 55ms/step - accuracy: 0.3682 - loss: 1.6049 - val_accuracy: 0.4401 - val_loss: 1.4471 - learning_rate: 0.0100
# Epoch 3/50
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 50s 55ms/step - accuracy: 0.4274 - loss: 1.4766 - val_accuracy: 0.4605 - val_loss: 1.3886 - learning_rate: 0.0100
# Epoch 4/50
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 50s 56ms/step - accuracy: 0.4580 - loss: 1.4063 - val_accuracy: 0.4492 - val_loss: 1.4644 - learning_rate: 0.0100
# Epoch 5/50
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 50s 56ms/step - accuracy: 0.4845 - loss: 1.3576 - val_accuracy: 0.4873 - val_loss: 1.3409 - learning_rate: 0.0100
# Epoch 6/50
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 50s 55ms/step - accuracy: 0.5014 - loss: 1.3217 - val_accuracy: 0.5408 - val_loss: 1.2130 - learning_rate: 0.0100
# Epoch 7/50
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 50s 56ms/step - accuracy: 0.5110 - loss: 1.2919 - val_accuracy: 0.5350 - val_loss: 1.2341 - learning_rate: 0.0100
# Epoch 8/50
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 50s 55ms/step - accuracy: 0.5229 - loss: 1.2692 - val_accuracy: 0.5522 - val_loss: 1.1963 - learning_rate: 0.0100
# Epoch 9/50
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 50s 56ms/step - accuracy: 0.5377 - loss: 1.2407 - val_accuracy: 0.5488 - val_loss: 1.1981 - learning_rate: 0.0100
# Epoch 10/50
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 50s 55ms/step - accuracy: 0.5391 - loss: 1.2278 - val_accuracy: 0.5454 - val_loss: 1.1854 - learning_rate: 0.0100
# Epoch 11/50
# 900/901 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.5534 - loss: 1.2065
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.007499999832361937.
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 50s 56ms/step - accuracy: 0.5542 - loss: 1.1996 - val_accuracy: 0.5477 - val_loss: 1.2019 - learning_rate: 0.0100
# Epoch 12/50
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 50s 55ms/step - accuracy: 0.5724 - loss: 1.1559 - val_accuracy: 0.5528 - val_loss: 1.1979 - learning_rate: 0.0075
# Epoch 13/50
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 50s 55ms/step - accuracy: 0.5793 - loss: 1.1366 - val_accuracy: 0.5777 - val_loss: 1.1250 - learning_rate: 0.0075
# Epoch 14/50
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 50s 55ms/step - accuracy: 0.5857 - loss: 1.1231 - val_accuracy: 0.5797 - val_loss: 1.1192 - learning_rate: 0.0075
# Epoch 15/50
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 50s 55ms/step - accuracy: 0.5954 - loss: 1.1071 - val_accuracy: 0.5846 - val_loss: 1.1101 - learning_rate: 0.0075
# Epoch 16/50
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 50s 55ms/step - accuracy: 0.6002 - loss: 1.0901 - val_accuracy: 0.5852 - val_loss: 1.1124 - learning_rate: 0.0075
# Epoch 17/50
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 50s 55ms/step - accuracy: 0.6047 - loss: 1.0757 - val_accuracy: 0.5894 - val_loss: 1.1041 - learning_rate: 0.0075
# Epoch 18/50
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 50s 55ms/step - accuracy: 0.6119 - loss: 1.0625 - val_accuracy: 0.5964 - val_loss: 1.0849 - learning_rate: 0.0075
# Epoch 19/50
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 50s 56ms/step - accuracy: 0.6145 - loss: 1.0509 - val_accuracy: 0.6148 - val_loss: 1.0339 - learning_rate: 0.0075
# Epoch 20/50
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 50s 55ms/step - accuracy: 0.6155 - loss: 1.0468 - val_accuracy: 0.6073 - val_loss: 1.0615 - learning_rate: 0.0075
# Epoch 21/50
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 50s 55ms/step - accuracy: 0.6263 - loss: 1.0236 - val_accuracy: 0.5835 - val_loss: 1.1196 - learning_rate: 0.0075
# Epoch 22/50
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 50s 55ms/step - accuracy: 0.6282 - loss: 1.0215 - val_accuracy: 0.6176 - val_loss: 1.0621 - learning_rate: 0.0075
# Epoch 23/50
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 50s 55ms/step - accuracy: 0.6308 - loss: 1.0113 - val_accuracy: 0.6057 - val_loss: 1.0756 - learning_rate: 0.0075
# Epoch 24/50
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 50s 55ms/step - accuracy: 0.6401 - loss: 0.9881 - val_accuracy: 0.5815 - val_loss: 1.1845 - learning_rate: 0.0075
# Epoch 25/50
# 900/901 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.6395 - loss: 0.9948
# Epoch 25: ReduceLROnPlateau reducing learning rate to 0.005624999874271452.
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 50s 55ms/step - accuracy: 0.6434 - loss: 0.9865 - val_accuracy: 0.6059 - val_loss: 1.0800 - learning_rate: 0.0075
# Epoch 26/50
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 50s 56ms/step - accuracy: 0.6534 - loss: 0.9573 - val_accuracy: 0.6237 - val_loss: 1.0419 - learning_rate: 0.0056
# Epoch 27/50
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 50s 56ms/step - accuracy: 0.6545 - loss: 0.9485 - val_accuracy: 0.6093 - val_loss: 1.1075 - learning_rate: 0.0056
# Epoch 28/50
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 50s 55ms/step - accuracy: 0.6667 - loss: 0.9293 - val_accuracy: 0.6009 - val_loss: 1.1376 - learning_rate: 0.0056
# Epoch 29/50
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 50s 55ms/step - accuracy: 0.6714 - loss: 0.9201 - val_accuracy: 0.6322 - val_loss: 1.0337 - learning_rate: 0.0056
# Epoch 30/50
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 50s 55ms/step - accuracy: 0.6723 - loss: 0.9113 - val_accuracy: 0.6016 - val_loss: 1.1461 - learning_rate: 0.0056
# Epoch 31/50
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 50s 56ms/step - accuracy: 0.6736 - loss: 0.9089 - val_accuracy: 0.6407 - val_loss: 1.0178 - learning_rate: 0.0056
# Epoch 32/50
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 50s 56ms/step - accuracy: 0.6782 - loss: 0.8965 - val_accuracy: 0.6247 - val_loss: 1.0490 - learning_rate: 0.0056
# Epoch 33/50
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 51s 57ms/step - accuracy: 0.6781 - loss: 0.8881 - val_accuracy: 0.6279 - val_loss: 1.0537 - learning_rate: 0.0056
# Epoch 34/50
# 900/901 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.6798 - loss: 0.8922
# Epoch 34: ReduceLROnPlateau reducing learning rate to 0.004218749818392098.
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 51s 57ms/step - accuracy: 0.6827 - loss: 0.8788 - val_accuracy: 0.6269 - val_loss: 1.0603 - learning_rate: 0.0056
# Epoch 35/50
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 51s 56ms/step - accuracy: 0.6912 - loss: 0.8639 - val_accuracy: 0.6264 - val_loss: 1.0799 - learning_rate: 0.0042
# Epoch 36/50
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 51s 57ms/step - accuracy: 0.7022 - loss: 0.8370 - val_accuracy: 0.6278 - val_loss: 1.0807 - learning_rate: 0.0042
# Epoch 37/50
# 900/901 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.6972 - loss: 0.8394
# Epoch 37: ReduceLROnPlateau reducing learning rate to 0.003164062276482582.
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 52s 57ms/step - accuracy: 0.7013 - loss: 0.8298 - val_accuracy: 0.6354 - val_loss: 1.0765 - learning_rate: 0.0042
# Epoch 38/50
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 52s 58ms/step - accuracy: 0.7107 - loss: 0.8216 - val_accuracy: 0.6477 - val_loss: 1.0110 - learning_rate: 0.0032
# Epoch 39/50
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 53s 59ms/step - accuracy: 0.7113 - loss: 0.8072 - val_accuracy: 0.6482 - val_loss: 1.0014 - learning_rate: 0.0032
# Epoch 40/50
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 53s 59ms/step - accuracy: 0.7131 - loss: 0.8097 - val_accuracy: 0.6383 - val_loss: 1.0403 - learning_rate: 0.0032
# Epoch 41/50
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 52s 57ms/step - accuracy: 0.7175 - loss: 0.7975 - val_accuracy: 0.6404 - val_loss: 1.0353 - learning_rate: 0.0032
# Epoch 42/50
# 900/901 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.7214 - loss: 0.7907
# Epoch 42: ReduceLROnPlateau reducing learning rate to 0.0023730467073619366.
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 51s 57ms/step - accuracy: 0.7214 - loss: 0.7883 - val_accuracy: 0.6411 - val_loss: 1.0433 - learning_rate: 0.0032
# Epoch 43/50
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 51s 56ms/step - accuracy: 0.7250 - loss: 0.7730 - val_accuracy: 0.6470 - val_loss: 1.0436 - learning_rate: 0.0024
# Epoch 44/50
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 51s 57ms/step - accuracy: 0.7237 - loss: 0.7789 - val_accuracy: 0.6393 - val_loss: 1.0512 - learning_rate: 0.0024
# Epoch 45/50
# 900/901 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.7272 - loss: 0.7760
# Epoch 45: ReduceLROnPlateau reducing learning rate to 0.0017797850305214524.
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 51s 57ms/step - accuracy: 0.7319 - loss: 0.7617 - val_accuracy: 0.6469 - val_loss: 1.0463 - learning_rate: 0.0024
# Epoch 46/50
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 51s 56ms/step - accuracy: 0.7313 - loss: 0.7560 - val_accuracy: 0.6400 - val_loss: 1.0370 - learning_rate: 0.0018
# Epoch 47/50
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 50s 56ms/step - accuracy: 0.7316 - loss: 0.7535 - val_accuracy: 0.6459 - val_loss: 1.0206 - learning_rate: 0.0018
# Epoch 48/50
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 50s 56ms/step - accuracy: 0.7380 - loss: 0.7427 - val_accuracy: 0.6500 - val_loss: 1.0218 - learning_rate: 0.0018
# Epoch 49/50
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 51s 56ms/step - accuracy: 0.7407 - loss: 0.7357 - val_accuracy: 0.6422 - val_loss: 1.0380 - learning_rate: 0.0018
# Epoch 50/50
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 51s 56ms/step - accuracy: 0.7395 - loss: 0.7314 - val_accuracy: 0.6388 - val_loss: 1.0662 - learning_rate: 0.0018

# %%
test_loss, test_acc = model.evaluate(val_ds)
print(f"Validation accuracy: {test_acc * 100:.2f}%")
# Out:
# 221/221 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.6388 - loss: 1.0662
# Validation accuracy: 63.88%

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Val Accuracy')

plt.title("Accuracy over Epochs")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')

plt.title("Loss over Epochs")
plt.xlabel("Epoch")
plt.ylabel("Cross Entropy Loss")
plt.legend()
plt.grid(True)
plt.show()
