# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

train_ds = tf.keras.utils.image_dataset_from_directory(
    "../images/train",
    color_mode="rgb",          
    image_size=(48, 48),
    batch_size=32,
    shuffle=True
)

val_ds = tf.keras.utils.image_dataset_from_directory(
    "../images/validation",
    color_mode="rgb",
    image_size=(48, 48),
    batch_size=32
)

class_names = train_ds.class_names
print("Detected classes:", class_names)


model = keras.Sequential([
    layers.Rescaling(1./255, input_shape=(48, 48, 3)),

    layers.Conv2D(512, (3,3), activation='relu', padding='same'),
    layers.BatchNormalization(),
    layers.MaxPooling2D(2, 2),
    layers.Dropout(0.25),

    layers.Conv2D(256, (3,3), activation='relu', padding='same'),
    layers.BatchNormalization(),
    layers.MaxPooling2D(2, 2),
    layers.Dropout(0.25),

    layers.Conv2D(128, (3,3), activation='relu', padding='same'),
    layers.BatchNormalization(),
    layers.MaxPooling2D(2, 2),
    layers.Dropout(0.3),

    layers.Flatten(),
    layers.Dense(64, activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.4),

    layers.Dense(len(class_names), activation='softmax')
])


model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=50,
)

test_loss, test_acc = model.evaluate(val_ds)
print(f"Validation accuracy: {test_acc * 100:.2f}%")
# Out:
# 2025-11-07 23:47:46.973916: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Found 28822 files belonging to 7 classes.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1762539473.112758   76700 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2140 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3050 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6
# Found 7066 files belonging to 7 classes.
# Detected classes: ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']
# /home/ikshvaku/Python-Env/fea/lib/python3.12/site-packages/keras/src/layers/preprocessing/data_layer.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/50
# 2025-11-07 23:47:58.490472: I external/local_xla/xla/service/service.cc:163] XLA service 0x7d9fc80076f0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2025-11-07 23:47:58.490519: I external/local_xla/xla/service/service.cc:171]   StreamExecutor device (0): NVIDIA GeForce RTX 3050 Laptop GPU, Compute Capability 8.6
# 2025-11-07 23:47:58.544875: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-11-07 23:47:58.941083: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:473] Loaded cuDNN version 91400
# 2025-11-07 23:47:59.229292: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-07 23:48:00.355778: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_3156', 520 bytes spill stores, 520 bytes spill loads
#   3/901 ━━━━━━━━━━━━━━━━━━━━ 1:00 67ms/step - accuracy: 0.1510 - loss: 2.8709
# I0000 00:00:1762539491.281881   76807 device_compiler.h:196] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 102s 96ms/step - accuracy: 0.2360 - loss: 2.2858 - val_accuracy: 0.3824 - val_loss: 1.6404 - learning_rate: 1.0000e-04
# Epoch 2/50
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 58s 64ms/step - accuracy: 0.3268 - loss: 1.9082 - val_accuracy: 0.4387 - val_loss: 1.5151 - learning_rate: 1.0000e-04
# Epoch 3/50
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 51s 56ms/step - accuracy: 0.3813 - loss: 1.7250 - val_accuracy: 0.4673 - val_loss: 1.4261 - learning_rate: 1.0000e-04
# Epoch 4/50
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 51s 56ms/step - accuracy: 0.4185 - loss: 1.5819 - val_accuracy: 0.4973 - val_loss: 1.3486 - learning_rate: 1.0000e-04
# Epoch 5/50
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 52s 57ms/step - accuracy: 0.4525 - loss: 1.4760 - val_accuracy: 0.3847 - val_loss: 1.5899 - learning_rate: 1.0000e-04
# Epoch 6/50
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 51s 56ms/step - accuracy: 0.4819 - loss: 1.3901 - val_accuracy: 0.5115 - val_loss: 1.2886 - learning_rate: 1.0000e-04
# Epoch 7/50
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 51s 57ms/step - accuracy: 0.4990 - loss: 1.3302 - val_accuracy: 0.5248 - val_loss: 1.2750 - learning_rate: 1.0000e-04
# Epoch 8/50
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 50s 56ms/step - accuracy: 0.5152 - loss: 1.2862 - val_accuracy: 0.5352 - val_loss: 1.2455 - learning_rate: 1.0000e-04
# Epoch 9/50
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 50s 56ms/step - accuracy: 0.5327 - loss: 1.2417 - val_accuracy: 0.5555 - val_loss: 1.1952 - learning_rate: 1.0000e-04
# Epoch 10/50
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 51s 56ms/step - accuracy: 0.5508 - loss: 1.2041 - val_accuracy: 0.5623 - val_loss: 1.1730 - learning_rate: 1.0000e-04
# Epoch 11/50
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 51s 56ms/step - accuracy: 0.5610 - loss: 1.1721 - val_accuracy: 0.5293 - val_loss: 1.2505 - learning_rate: 1.0000e-04
# Epoch 12/50
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 50s 56ms/step - accuracy: 0.5726 - loss: 1.1398 - val_accuracy: 0.5693 - val_loss: 1.1447 - learning_rate: 1.0000e-04
# Epoch 13/50
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 50s 56ms/step - accuracy: 0.5826 - loss: 1.1181 - val_accuracy: 0.5791 - val_loss: 1.1342 - learning_rate: 1.0000e-04
# Epoch 14/50
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 50s 56ms/step - accuracy: 0.5970 - loss: 1.0846 - val_accuracy: 0.5773 - val_loss: 1.1344 - learning_rate: 1.0000e-04
# Epoch 15/50
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 50s 56ms/step - accuracy: 0.6051 - loss: 1.0622 - val_accuracy: 0.5270 - val_loss: 1.2490 - learning_rate: 1.0000e-04
# Epoch 16/50
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 50s 56ms/step - accuracy: 0.6136 - loss: 1.0416 - val_accuracy: 0.5815 - val_loss: 1.1136 - learning_rate: 1.0000e-04
# Epoch 17/50
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 50s 56ms/step - accuracy: 0.6284 - loss: 1.0083 - val_accuracy: 0.5928 - val_loss: 1.0993 - learning_rate: 1.0000e-04
# Epoch 18/50
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 51s 56ms/step - accuracy: 0.6314 - loss: 0.9866 - val_accuracy: 0.6145 - val_loss: 1.0569 - learning_rate: 1.0000e-04
# Epoch 19/50
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 50s 56ms/step - accuracy: 0.6411 - loss: 0.9686 - val_accuracy: 0.6037 - val_loss: 1.0797 - learning_rate: 1.0000e-04
# Epoch 20/50
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 50s 56ms/step - accuracy: 0.6511 - loss: 0.9452 - val_accuracy: 0.6073 - val_loss: 1.0656 - learning_rate: 1.0000e-04
# Epoch 21/50
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 50s 56ms/step - accuracy: 0.6607 - loss: 0.9242 - val_accuracy: 0.5933 - val_loss: 1.1033 - learning_rate: 1.0000e-04
# Epoch 22/50
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 50s 56ms/step - accuracy: 0.6765 - loss: 0.8830 - val_accuracy: 0.6179 - val_loss: 1.0536 - learning_rate: 5.0000e-05
# Epoch 23/50
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 51s 56ms/step - accuracy: 0.6856 - loss: 0.8596 - val_accuracy: 0.6231 - val_loss: 1.0379 - learning_rate: 5.0000e-05
# Epoch 24/50
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 51s 56ms/step - accuracy: 0.6884 - loss: 0.8433 - val_accuracy: 0.6251 - val_loss: 1.0331 - learning_rate: 5.0000e-05
# Epoch 25/50
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 51s 56ms/step - accuracy: 0.6959 - loss: 0.8258 - val_accuracy: 0.6274 - val_loss: 1.0299 - learning_rate: 5.0000e-05
# Epoch 26/50
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 51s 56ms/step - accuracy: 0.7045 - loss: 0.8154 - val_accuracy: 0.6289 - val_loss: 1.0219 - learning_rate: 5.0000e-05
# Epoch 27/50
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 51s 56ms/step - accuracy: 0.7068 - loss: 0.8033 - val_accuracy: 0.6139 - val_loss: 1.0605 - learning_rate: 5.0000e-05
# Epoch 28/50
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 50s 56ms/step - accuracy: 0.7136 - loss: 0.7858 - val_accuracy: 0.6221 - val_loss: 1.0495 - learning_rate: 5.0000e-05
# Epoch 29/50
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 50s 56ms/step - accuracy: 0.7194 - loss: 0.7694 - val_accuracy: 0.6187 - val_loss: 1.0422 - learning_rate: 5.0000e-05
# Epoch 30/50
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 50s 56ms/step - accuracy: 0.7233 - loss: 0.7539 - val_accuracy: 0.6291 - val_loss: 1.0320 - learning_rate: 2.5000e-05
# Epoch 31/50
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 50s 56ms/step - accuracy: 0.7296 - loss: 0.7369 - val_accuracy: 0.6269 - val_loss: 1.0392 - learning_rate: 2.5000e-05
# Epoch 32/50
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 51s 56ms/step - accuracy: 0.7319 - loss: 0.7369 - val_accuracy: 0.6261 - val_loss: 1.0452 - learning_rate: 2.5000e-05
# Epoch 33/50
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 51s 56ms/step - accuracy: 0.7348 - loss: 0.7226 - val_accuracy: 0.6327 - val_loss: 1.0302 - learning_rate: 1.2500e-05
# Epoch 34/50
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 51s 56ms/step - accuracy: 0.7396 - loss: 0.7148 - val_accuracy: 0.6318 - val_loss: 1.0333 - learning_rate: 1.2500e-05
# Epoch 35/50
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 50s 56ms/step - accuracy: 0.7423 - loss: 0.7098 - val_accuracy: 0.6294 - val_loss: 1.0336 - learning_rate: 1.2500e-05
# Epoch 36/50
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 50s 56ms/step - accuracy: 0.7451 - loss: 0.6960 - val_accuracy: 0.6360 - val_loss: 1.0257 - learning_rate: 6.2500e-06
# Epoch 37/50
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 50s 56ms/step - accuracy: 0.7458 - loss: 0.6959 - val_accuracy: 0.6352 - val_loss: 1.0321 - learning_rate: 6.2500e-06
# Epoch 38/50
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 50s 56ms/step - accuracy: 0.7494 - loss: 0.6938 - val_accuracy: 0.6344 - val_loss: 1.0280 - learning_rate: 6.2500e-06
# Epoch 39/50
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 51s 56ms/step - accuracy: 0.7458 - loss: 0.6952 - val_accuracy: 0.6353 - val_loss: 1.0304 - learning_rate: 3.1250e-06
# Epoch 40/50
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 51s 56ms/step - accuracy: 0.7484 - loss: 0.6928 - val_accuracy: 0.6346 - val_loss: 1.0278 - learning_rate: 3.1250e-06
# Epoch 41/50
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 51s 56ms/step - accuracy: 0.7470 - loss: 0.6972 - val_accuracy: 0.6340 - val_loss: 1.0269 - learning_rate: 3.1250e-06
# Epoch 42/50
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 51s 56ms/step - accuracy: 0.7461 - loss: 0.6879 - val_accuracy: 0.6360 - val_loss: 1.0273 - learning_rate: 1.5625e-06
# Epoch 43/50
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 50s 56ms/step - accuracy: 0.7522 - loss: 0.6826 - val_accuracy: 0.6359 - val_loss: 1.0249 - learning_rate: 1.5625e-06
# Epoch 44/50
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 50s 56ms/step - accuracy: 0.7454 - loss: 0.6925 - val_accuracy: 0.6364 - val_loss: 1.0258 - learning_rate: 1.5625e-06
# Epoch 45/50
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 51s 56ms/step - accuracy: 0.7513 - loss: 0.6830 - val_accuracy: 0.6360 - val_loss: 1.0252 - learning_rate: 1.0000e-06
# Epoch 46/50
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 51s 56ms/step - accuracy: 0.7561 - loss: 0.6789 - val_accuracy: 0.6359 - val_loss: 1.0254 - learning_rate: 1.0000e-06
# Epoch 47/50
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 51s 57ms/step - accuracy: 0.7492 - loss: 0.6838 - val_accuracy: 0.6360 - val_loss: 1.0251 - learning_rate: 1.0000e-06
# Epoch 48/50
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 51s 57ms/step - accuracy: 0.7561 - loss: 0.6757 - val_accuracy: 0.6360 - val_loss: 1.0260 - learning_rate: 1.0000e-06
# Epoch 49/50
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 51s 56ms/step - accuracy: 0.7510 - loss: 0.6836 - val_accuracy: 0.6367 - val_loss: 1.0265 - learning_rate: 1.0000e-06
# Epoch 50/50
# 901/901 ━━━━━━━━━━━━━━━━━━━━ 51s 56ms/step - accuracy: 0.7507 - loss: 0.6841 - val_accuracy: 0.6363 - val_loss: 1.0262 - learning_rate: 1.0000e-06
# 221/221 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.6363 - loss: 1.0262
# Validation accuracy: 63.63%
